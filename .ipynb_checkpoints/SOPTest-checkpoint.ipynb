# %%
import numpy as np
import scipy.io

# %%
mat = scipy.io.loadmat('data3SS.mat')

# %%
from matplotlib import pyplot as plt

# %%
data = mat['dataset']

# %%
from statsmodels.tsa.ar_model import AR,ARResults

# %%
plt.plot(data[:,4,809],'r')
#plt.plot(data[:,4,2],'g')
plt.xlabel('Time Step')
plt.ylabel('Accelaration')
# Out:
# Text(0,0.5,'Accelaration')

# %%
temp = np.zeros(37)
for i in range(3,5):
    test = data[:,i,1]
    print(i)
    model = AR(test)
    fi = model.fit()
    temp = temp+fi.params
# Out:
# 3
# 4

# %%
model2 = AR(test)
model_fit2 = model.fit()

# %%
from statsmodels.tsa.ar_model import ARResults

# %%
plt.plot(model_fit.params)
plt.plot(model_fit2.params)
plt.show()

# %%
print(model_fit.k_ar)
print(model_fit2.k_ar)
# Out:
# 36
# 36

# %%
plt.plot(model_fit.params)
plt.plot(model_fit2.params)

# %%
plt.plot()

# %%
plt.plot(fi.params)

# %%
plt.plot(temp/5)

# %%
std = np.std(temp)
mean = np.mean(temp)
temp = (temp - mean)/std

# %%
plt.plot(temp/5)

# %%
x = [i for i in range(1,38)]

# %%
plt.plot(x,temp,'-o')
plt.plot(x,temp1,'-o')
plt.xlabel('Auto Regressive Parameters')
plt.ylabel('Amplitude')
plt.show()

# %%
temp1 = temp

# %%
model = AR(data[:,1,1])

# %%
model.select_order(45,'aic')
# Out:
# 45

# %%
from models import autoregressive as ar

# %%
import scipy.io

# %%
data = ar.load_data('data3SS.mat')

# %%
data.shape
# Out:
# (8192, 5, 850)

# %%
ar.plot_signal(data,2,50)

# %%
d = ar.fit_AR(data[:,1,1])

# %%
d.params
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-9d0442c39b55> in <module>()
# ----> 1 d.params
#
# AttributeError: 'function' object has no attribute 'params'
